# %%
# !pip install super-gradients==3.2.0
# !pip install imutils
# !pip install roboflow
# Out:
# Collecting super-gradients==3.2.0
#   Downloading super_gradients-3.2.0-py3-none-any.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 690.7 kB/s eta 0:00:0000:0100:01
# Collecting coverage~=5.3.1
#   Using cached coverage-5.3.1-cp310-cp310-linux_x86_64.whl
# Collecting json-tricks==3.16.1
#   Downloading json_tricks-3.16.1-py2.py3-none-any.whl (27 kB)
# Collecting torchmetrics==0.8
#   Downloading torchmetrics-0.8.0-py3-none-any.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 KB 429.5 kB/s eta 0:00:0000:0100:01
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 925.0 kB/s eta 0:00:0000:0100:01
# Collecting wheel>=0.38.0
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Requirement already satisfied: pillow!=8.3,>=5.3.0 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (11.1.0)
# Requirement already satisfied: psutil>=5.8.0 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (7.0.0)
# Requirement already satisfied: torchvision>=0.10.0 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (0.21.0)
# Requirement already satisfied: pygments>=2.7.4 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (2.19.1)
# Requirement already satisfied: jsonschema>=3.2.0 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (4.23.0)
# Requirement already satisfied: tqdm>=4.57.0 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (4.67.1)
# Requirement already satisfied: hydra-core>=1.2.0 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (1.3.2)
# Collecting onnxruntime==1.13.1
#   Downloading onnxruntime-1.13.1-cp310-cp310-manylinux_2_27_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 585.3 kB/s eta 0:00:0000:0100:01
# Collecting stringcase>=1.2.0
#   Using cached stringcase-1.2.0-py3-none-any.whl
# Requirement already satisfied: packaging>=20.4 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (24.2)
# Requirement already satisfied: setuptools>=21.0.0 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (59.6.0)
# Collecting onnx==1.13.0
#   Downloading onnx-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 1.2 MB/s eta 0:00:0000:0100:01m
# Collecting pyparsing==2.4.5
#   Downloading pyparsing-2.4.5-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 KB 785.4 kB/s eta 0:00:00 0:00:01m
# Requirement already satisfied: scipy>=1.6.1 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (1.15.2)
# Requirement already satisfied: tensorboard>=2.4.1 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (2.19.0)
# Collecting numpy<=1.23
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 1.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: torch>=1.9.0 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (2.6.0)
# Requirement already satisfied: opencv-python>=4.5.1 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (4.11.0.86)
# Collecting sphinx~=4.0.2
#   Downloading Sphinx-4.0.3-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.4 MB/s eta 0:00:0000:0100:010m
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 607.5 kB/s eta 0:00:0000:0100:01
# Collecting Deprecated>=1.2.11
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Collecting treelib==1.6.1
#   Using cached treelib-1.6.1-py3-none-any.whl
# Collecting boto3>=1.17.15
#   Downloading boto3-1.37.8-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 KB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting termcolor==1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting einops==0.3.2
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: omegaconf in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (2.3.0)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 1.1 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: matplotlib>=3.3.4 in ./skyenv/lib/python3.10/site-packages (from super-gradients==3.2.0) (3.10.0)
# Collecting pycocotools==2.0.6
#   Downloading pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pip-tools>=6.12.1
#   Downloading pip_tools-7.4.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 KB 218.1 kB/s eta 0:00:00a 0:00:01
# Collecting onnx-simplifier<1.0,>=0.3.6
#   Downloading onnx_simplifier-0.4.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 1.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=3.6.2.1 in ./skyenv/lib/python3.10/site-packages (from onnx==1.13.0->super-gradients==3.2.0) (4.12.2)
# Requirement already satisfied: flatbuffers in ./skyenv/lib/python3.10/site-packages (from onnxruntime==1.13.1->super-gradients==3.2.0) (25.2.10)
# Requirement already satisfied: sympy in ./skyenv/lib/python3.10/site-packages (from onnxruntime==1.13.1->super-gradients==3.2.0) (1.13.1)
# Requirement already satisfied: coloredlogs in ./skyenv/lib/python3.10/site-packages (from onnxruntime==1.13.1->super-gradients==3.2.0) (15.0.1)
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting future
#   Downloading future-1.0.0-py3-none-any.whl (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 KB 1.0 MB/s eta 0:00:0000:0100:01
# Collecting s3transfer<0.12.0,>=0.11.0
#   Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 KB 851.7 kB/s eta 0:00:00a 0:00:01
# Collecting jmespath<2.0.0,>=0.7.1
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.38.0,>=1.37.8
#   Downloading botocore-1.37.8-py3-none-any.whl (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 3.0 MB/s eta 0:00:0000:0100:01
# Collecting wrapt<2,>=1.10
#   Using cached wrapt-1.17.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./skyenv/lib/python3.10/site-packages (from hydra-core>=1.2.0->super-gradients==3.2.0) (4.9.3)
# Requirement already satisfied: rpds-py>=0.7.1 in ./skyenv/lib/python3.10/site-packages (from jsonschema>=3.2.0->super-gradients==3.2.0) (0.22.3)
# Requirement already satisfied: attrs>=22.2.0 in ./skyenv/lib/python3.10/site-packages (from jsonschema>=3.2.0->super-gradients==3.2.0) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./skyenv/lib/python3.10/site-packages (from jsonschema>=3.2.0->super-gradients==3.2.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in ./skyenv/lib/python3.10/site-packages (from jsonschema>=3.2.0->super-gradients==3.2.0) (0.36.2)
# Requirement already satisfied: cycler>=0.10 in ./skyenv/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients==3.2.0) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./skyenv/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients==3.2.0) (1.4.8)
# Requirement already satisfied: python-dateutil>=2.7 in ./skyenv/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients==3.2.0) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in ./skyenv/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients==3.2.0) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./skyenv/lib/python3.10/site-packages (from matplotlib>=3.3.4->super-gradients==3.2.0) (4.56.0)
# Requirement already satisfied: PyYAML>=5.1.0 in ./skyenv/lib/python3.10/site-packages (from omegaconf->super-gradients==3.2.0) (6.0.2)
# Collecting rich
#   Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Collecting pyproject-hooks
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: click>=8 in ./skyenv/lib/python3.10/site-packages (from pip-tools>=6.12.1->super-gradients==3.2.0) (8.1.8)
# Collecting build>=1.0.0
#   Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Requirement already satisfied: tomli in ./skyenv/lib/python3.10/site-packages (from pip-tools>=6.12.1->super-gradients==3.2.0) (2.2.1)
# Collecting pip>=22.2
#   Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.6 MB/s eta 0:00:0000:0100:01
# Collecting scipy>=1.6.1
#   Downloading scipy-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 3.7 MB/s eta 0:00:0000:0100:01
#   Downloading scipy-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 1.5 MB/s eta 0:00:0000:0100:01
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 1.2 MB/s eta 0:00:0000:0100:01m
#   Downloading scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 MB 1.9 MB/s eta 0:00:0000:0100:01
#   Downloading scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 1.8 MB/s eta 0:00:0000:0100:01
# Collecting docutils<0.18,>=0.14
#   Downloading docutils-0.17.1-py2.py3-none-any.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.5/575.5 KB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 KB 2.9 MB/s eta 0:00:00
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 KB 87.6 kB/s eta 0:00:0000:0100:01
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 KB 859.1 kB/s eta 0:00:000:010m
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 KB 3.0 MB/s eta 0:00:00
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 KB 1.0 MB/s eta 0:00:00a 0:00:01
# Collecting imagesize
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: Jinja2>=2.3 in ./skyenv/lib/python3.10/site-packages (from sphinx~=4.0.2->super-gradients==3.2.0) (3.1.5)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.16-py3-none-any.whl (13 kB)
# Collecting babel>=1.3
#   Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 2.4 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: requests>=2.5.0 in ./skyenv/lib/python3.10/site-packages (from sphinx~=4.0.2->super-gradients==3.2.0) (2.32.3)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./skyenv/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients==3.2.0) (0.7.2)
# Requirement already satisfied: grpcio>=1.48.2 in ./skyenv/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients==3.2.0) (1.70.0)
# Requirement already satisfied: absl-py>=0.4 in ./skyenv/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients==3.2.0) (2.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./skyenv/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients==3.2.0) (3.1.3)
# Requirement already satisfied: six>1.9 in ./skyenv/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients==3.2.0) (1.17.0)
# Requirement already satisfied: markdown>=2.6.8 in ./skyenv/lib/python3.10/site-packages (from tensorboard>=2.4.1->super-gradients==3.2.0) (3.7)
# Requirement already satisfied: networkx in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (3.4.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (12.4.127)
# Requirement already satisfied: filelock in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (3.17.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (11.6.1.9)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (12.4.5.8)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (12.4.127)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (2.21.5)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (3.2.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (11.2.1.3)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (0.6.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (12.3.1.170)
# Requirement already satisfied: fsspec in ./skyenv/lib/python3.10/site-packages (from torch>=1.9.0->super-gradients==3.2.0) (2025.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./skyenv/lib/python3.10/site-packages (from sympy->onnxruntime==1.13.1->super-gradients==3.2.0) (1.3.0)
# Collecting sphinxcontrib-jquery<5,>=4
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 3.1 MB/s eta 0:00:00a 0:00:01
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-3.0.1-py2.py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 1.3 MB/s eta 0:00:0000:0100:010m
#   Downloading sphinx_rtd_theme-3.0.0-py2.py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 2.6 MB/s eta 0:00:0000:0100:01
#   Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 3.5 MB/s eta 0:00:0000:0100:01
#   Downloading sphinx_rtd_theme-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 540.4 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in ./skyenv/lib/python3.10/site-packages (from botocore<1.38.0,>=1.37.8->boto3>=1.17.15->super-gradients==3.2.0) (2.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./skyenv/lib/python3.10/site-packages (from Jinja2>=2.3->sphinx~=4.0.2->super-gradients==3.2.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./skyenv/lib/python3.10/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients==3.2.0) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./skyenv/lib/python3.10/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients==3.2.0) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in ./skyenv/lib/python3.10/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super-gradients==3.2.0) (3.10)
# Requirement already satisfied: humanfriendly>=9.1 in ./skyenv/lib/python3.10/site-packages (from coloredlogs->onnxruntime==1.13.1->super-gradients==3.2.0) (10.0)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp310-cp310-linux_x86_64.whl size=377643 sha256=3a1d6ba89dbacedf166d49fc699509008ad72e95953f76903f9251bdd80ebb45
#   Stored in directory: /home/fahadabul/.cache/pip/wheels/58/e6/f9/f87c8f8be098b51b616871315318329cae12cdb618f4caac93
# Successfully built pycocotools
# Installing collected packages: termcolor, stringcase, snowballstemmer, json-tricks, einops, wrapt, wheel, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, rapidfuzz, pyproject-hooks, pyparsing, pyDeprecate, protobuf, pip, numpy, mdurl, jmespath, imagesize, future, docutils, coverage, babel, alabaster, treelib, sphinx, scipy, onnxruntime, onnx, markdown-it-py, Deprecated, build, botocore, sphinxcontrib-jquery, s3transfer, rich, pip-tools, torchmetrics, sphinx-rtd-theme, pycocotools, onnx-simplifier, boto3, super-gradients
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.5.0
#     Uninstalling termcolor-2.5.0:
#       Successfully uninstalled termcolor-2.5.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.1
#     Uninstalling pyparsing-3.2.1:
#       Successfully uninstalled pyparsing-3.2.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
#   Attempting uninstall: onnxruntime
#     Found existing installation: onnxruntime 1.20.1
#     Uninstalling onnxruntime-1.20.1:
#       Successfully uninstalled onnxruntime-1.20.1
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.8
#     Uninstalling pycocotools-2.0.8:
#       Successfully uninstalled pycocotools-2.0.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.25.1 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 1.23.0 which is incompatible.
# Successfully installed Deprecated-1.2.18 alabaster-0.7.16 babel-2.17.0 boto3-1.37.8 botocore-1.37.8 build-1.2.2.post1 coverage-5.3.1 docutils-0.17.1 einops-0.3.2 future-1.0.0 imagesize-1.4.1 jmespath-1.0.1 json-tricks-3.16.1 markdown-it-py-3.0.0 mdurl-0.1.2 numpy-1.23.0 onnx-1.13.0 onnx-simplifier-0.4.36 onnxruntime-1.13.1 pip-25.0.1 pip-tools-7.4.1 protobuf-3.20.3 pyDeprecate-0.3.2 pycocotools-2.0.6 pyparsing-2.4.5 pyproject-hooks-1.2.0 rapidfuzz-3.12.2 rich-13.9.4 s3transfer-0.11.4 scipy-1.13.1 snowballstemmer-2.2.0 sphinx-4.0.3 sphinx-rtd-theme-1.3.0 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0 stringcase-1.2.0 super-gradients-3.2.0 termcolor-1.1.0 torchmetrics-0.8.0 treelib-1.6.1 wheel-0.45.1 wrapt-1.17.2
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25861 sha256=f4f00cb9ad71bbbfcca3fd0bcec2b89bebd1c259616f1e4e7df8b0f55f72845d
#   Stored in directory: /home/fahadabul/.cache/pip/wheels/85/cf/3a/e265e975a1e7c7e54eb3692d6aa4e2e7d6a3945d29da46f2d7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Collecting roboflow
#   Downloading roboflow-1.1.54-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in ./skyenv/lib/python3.10/site-packages (from roboflow) (2025.1.31)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in ./skyenv/lib/python3.10/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./skyenv/lib/python3.10/site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in ./skyenv/lib/python3.10/site-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in ./skyenv/lib/python3.10/site-packages (from roboflow) (1.23.0)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in ./skyenv/lib/python3.10/site-packages (from roboflow) (11.1.0)
# Requirement already satisfied: python-dateutil in ./skyenv/lib/python3.10/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in ./skyenv/lib/python3.10/site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in ./skyenv/lib/python3.10/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in ./skyenv/lib/python3.10/site-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in ./skyenv/lib/python3.10/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in ./skyenv/lib/python3.10/site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./skyenv/lib/python3.10/site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./skyenv/lib/python3.10/site-packages (from matplotlib->roboflow) (4.56.0)
# Requirement already satisfied: packaging>=20.0 in ./skyenv/lib/python3.10/site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./skyenv/lib/python3.10/site-packages (from matplotlib->roboflow) (2.4.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./skyenv/lib/python3.10/site-packages (from requests->roboflow) (3.4.1)
# Downloading roboflow-1.1.54-py3-none-any.whl (83 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 1.5 MB/s eta 0:00:0000:0100:01
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: filetype, python-dotenv, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 python-dotenv-1.0.1 requests-toolbelt-1.0.0 roboflow-1.1.54

# %%
# !pip install --upgrade numpy
# !pip install --upgrade scikit-image numba
# !pip check
# Out:
# Requirement already satisfied: numpy in ./skyenv/lib/python3.10/site-packages (1.23.0)
# Collecting numpy
#   Downloading numpy-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Downloading numpy-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 1.5 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
#       Successfully uninstalled numpy-1.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.2.3 which is incompatible.
# super-gradients 3.2.0 requires numpy<=1.23, but you have numpy 2.2.3 which is incompatible.
# Successfully installed numpy-2.2.3
# Requirement already satisfied: scikit-image in ./skyenv/lib/python3.10/site-packages (0.25.1)
# Collecting scikit-image
#   Using cached scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numba in ./skyenv/lib/python3.10/site-packages (0.61.0)
# Requirement already satisfied: numpy>=1.24 in ./skyenv/lib/python3.10/site-packages (from scikit-image) (2.2.3)
# Requirement already satisfied: scipy>=1.11.4 in ./skyenv/lib/python3.10/site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in ./skyenv/lib/python3.10/site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in ./skyenv/lib/python3.10/site-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in ./skyenv/lib/python3.10/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./skyenv/lib/python3.10/site-packages (from scikit-image) (2025.1.10)
# Requirement already satisfied: packaging>=21 in ./skyenv/lib/python3.10/site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in ./skyenv/lib/python3.10/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in ./skyenv/lib/python3.10/site-packages (from numba) (0.44.0)
# Collecting numpy>=1.24 (from scikit-image)
#   Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 2.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy, scikit-image
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.1
#     Uninstalling scikit-image-0.25.1:
#       Successfully uninstalled scikit-image-0.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# super-gradients 3.2.0 requires numpy<=1.23, but you have numpy 2.1.3 which is incompatible.
# Successfully installed numpy-2.1.3 scikit-image-0.25.2
# super-gradients 3.2.0 has requirement numpy<=1.23, but you have numpy 2.1.3.

# %%
from super_gradients.training import models

yolo_nas_l = models.get("yolo_nas_l", pretrained_weights="coco")
# Out:
# [2025-03-07 16:46:28] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# The console stream is logged into /home/fahadabul/sg_logs/console.log
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from super_gradients.training import models
#       3 yolo_nas_l = models.get("yolo_nas_l", pretrained_weights="coco")
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/__init__.py:2
#       1 from super_gradients.common import init_trainer, is_distributed, object_names
# ----> 2 from super_gradients.training import losses, utils, datasets_utils, DataAugmentation, Trainer, KDTrainer, QATTrainer
#       3 from super_gradients.common.registry.registry import ARCHITECTURES
#       4 from super_gradients.sanity_check import env_sanity_check
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/__init__.py:2
#       1 # PACKAGE IMPORTS FOR EXTERNAL USAGE
# ----> 2 import super_gradients.training.utils.distributed_training_utils as distributed_training_utils
#       3 from super_gradients.training.datasets import datasets_utils, DataAugmentation
#       4 from super_gradients.training.sg_trainer import Trainer
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/utils/__init__.py:10
#       1 from super_gradients.training.utils.utils import (
#       2     Timer,
#       3     HpmStruct,
#    (...)
#       8     make_divisible,
#       9 )
# ---> 10 from super_gradients.training.utils.checkpoint_utils import adapt_state_dict_to_fit_model_layer_names, raise_informative_runtime_error
#      11 from super_gradients.training.utils.version_utils import torch_version_is_greater_or_equal
#      12 from super_gradients.training.utils.config_utils import raise_if_unused_params, warn_if_unused_params
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/utils/checkpoint_utils.py:14
#      12 from super_gradients.common.data_types import StrictLoad
#      13 from super_gradients.common.decorators.explicit_params_validator import explicit_params_validation
# ---> 14 from super_gradients.module_interfaces import HasPredict
#      15 from super_gradients.training.pretrained_models import MODEL_URLS
#      16 from super_gradients.training.utils.distributed_training_utils import get_local_rank, wait_for_the_master
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/module_interfaces/__init__.py:1
# ----> 1 from .module_interfaces import HasPredict, HasPreprocessingParams, SupportsReplaceNumClasses
#       2 from .exportable_detector import ExportableObjectDetectionModel, AbstractObjectDetectionDecodingModule
#       4 __all__ = ["HasPredict", "HasPreprocessingParams", "SupportsReplaceNumClasses", "ExportableObjectDetectionModel", "AbstractObjectDetectionDecodingModule"]
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/module_interfaces/module_interfaces.py:6
#       3 from torch import nn
#       4 from typing_extensions import Protocol, runtime_checkable
# ----> 6 from super_gradients.training.processing.processing import Processing
#       9 @runtime_checkable
#      10 class HasPreprocessingParams(Protocol):
#      11     """
#      12     Protocol interface for torch datasets that support getting preprocessing params, later to be passed to a model
#      13     that obeys NeedsPreprocessingParams. This interface class serves a purpose of explicitly indicating whether a torch dataset has
#      14     get_dataset_preprocessing_params implemented.
#      15
#      16     """
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/processing/__init__.py:1
# ----> 1 from .processing import (
#       2     StandardizeImage,
#       3     DetectionRescale,
#       4     DetectionLongestMaxSizeRescale,
#       5     DetectionBottomRightPadding,
#       6     DetectionCenterPadding,
#       7     ImagePermute,
#       8     ReverseImageChannels,
#       9     NormalizeImage,
#      10     ComposeProcessing,
#      11 )
#      13 __all__ = [
#      14     "StandardizeImage",
#      15     "DetectionRescale",
#    (...)
#      22     "ComposeProcessing",
#      23 ]
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/processing/processing.py:11
#       9 from super_gradients.common.object_names import Processings
#      10 from super_gradients.common.registry.registry import register_processing
# ---> 11 from super_gradients.training.datasets.datasets_conf import COCO_DETECTION_CLASSES_LIST, IMAGENET_CLASSES
#      12 from super_gradients.training.transforms.utils import (
#      13     _rescale_image,
#      14     _rescale_bboxes,
#    (...)
#      21     _shift_keypoints,
#      22 )
#      23 from super_gradients.training.utils.predict import Prediction, DetectionPrediction, PoseEstimationPrediction
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/datasets/__init__.py:7
#       5 from super_gradients.training.datasets.sg_dataset import ListDataset, DirectoryDataSet
#       6 from super_gradients.training.datasets.classification_datasets import ImageNetDataset, Cifar10, Cifar100
# ----> 7 from super_gradients.training.datasets.detection_datasets import (
#       8     DetectionDataset,
#       9     COCODetectionDataset,
#      10     PascalVOCDetectionDataset,
#      11     YoloDarknetFormatDetectionDataset,
#      12 )
#      13 from super_gradients.training.datasets.segmentation_datasets.segmentation_dataset import SegmentationDataSet
#      14 from super_gradients.training.datasets.segmentation_datasets.pascal_voc_segmentation import (
#      15     PascalVOC2012SegmentationDataSet,
#      16     PascalAUG2012SegmentationDataSet,
#      17     PascalVOCAndAUGUnifiedDataset,
#      18 )
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/datasets/detection_datasets/__init__.py:1
# ----> 1 from super_gradients.training.datasets.detection_datasets.coco_detection import COCODetectionDataset
#       2 from super_gradients.training.datasets.detection_datasets.pascal_voc_detection import PascalVOCDetectionDataset
#       3 from super_gradients.training.datasets.detection_datasets.detection_dataset import DetectionDataset
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/datasets/detection_datasets/coco_detection.py:6
#       4 from super_gradients.common.registry.registry import register_dataset
#       5 from super_gradients.common.abstractions.abstract_logger import get_logger
# ----> 6 from super_gradients.training.datasets.detection_datasets.coco_format_detection import COCOFormatDetectionDataset
#       8 logger = get_logger(__name__)
#      11 @register_dataset(Datasets.COCO_DETECTION_DATASET)
#      12 class COCODetectionDataset(COCOFormatDetectionDataset):
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/super_gradients/training/datasets/detection_datasets/coco_format_detection.py:6
#       4 import cv2
#       5 import numpy as np
# ----> 6 from pycocotools.coco import COCO
#       7 from typing import List, Optional
#       9 from contextlib import redirect_stdout
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/pycocotools/coco.py:52
#      50 import copy
#      51 import itertools
# ---> 52 from . import mask as maskUtils
#      53 import os
#      54 from collections import defaultdict
#
# File ~/mask_rcnn_skyhub/skyenv/lib/python3.10/site-packages/pycocotools/mask.py:3
#       1 __author__ = 'tsungyi'
# ----> 3 import pycocotools._mask as _mask
#       5 # Interface for manipulating masks stored in RLE format.
#       6 #
#       7 # RLE is a simple yet efficient format for storing binary masks. RLE
#    (...)
#      73 # Code written by Piotr Dollar and Tsung-Yi Lin, 2015.
#      74 # Licensed under the Simplified BSD License [see coco/license.txt]
#      76 iou         = _mask.iou
#
# File pycocotools/_mask.pyx:1, in init pycocotools._mask()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
